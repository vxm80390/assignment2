# %% [markdown]
# <a href="https://colab.research.google.com/github/vxm80390/assignment2/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout

import matplotlib.pyplot as plt

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# train the model and record the training history
history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
    epochs=20, batch_size=128)

# plot the training and validation accuracy and loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/20
# 469/469 [==============================] - 20s 38ms/step - loss: 0.2518 - accuracy: 0.9234 - val_loss: 0.1078 - val_accuracy: 0.9659
# Epoch 2/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.1019 - accuracy: 0.9683 - val_loss: 0.0821 - val_accuracy: 0.9737
# Epoch 3/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0742 - accuracy: 0.9769 - val_loss: 0.0779 - val_accuracy: 0.9759
# Epoch 4/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0579 - accuracy: 0.9814 - val_loss: 0.0642 - val_accuracy: 0.9812
# Epoch 5/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.0709 - val_accuracy: 0.9795
# Epoch 6/20
# 469/469 [==============================] - 11s 22ms/step - loss: 0.0384 - accuracy: 0.9876 - val_loss: 0.0601 - val_accuracy: 0.9833
# Epoch 7/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0344 - accuracy: 0.9890 - val_loss: 0.0633 - val_accuracy: 0.9827
# Epoch 8/20
# 469/469 [==============================] - 11s 22ms/step - loss: 0.0304 - accuracy: 0.9896 - val_loss: 0.0641 - val_accuracy: 0.9830
# Epoch 9/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0287 - accuracy: 0.9901 - val_loss: 0.0687 - val_accuracy: 0.9811
# Epoch 10/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0258 - accuracy: 0.9910 - val_loss: 0.0725 - val_accuracy: 0.9812
# Epoch 11/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0237 - accuracy: 0.9918 - val_loss: 0.0805 - val_accuracy: 0.9796
# Epoch 12/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0661 - val_accuracy: 0.9837
# Epoch 13/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 0.0792 - val_accuracy: 0.9805
# Epoch 14/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0787 - val_accuracy: 0.9820
# Epoch 15/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0694 - val_accuracy: 0.9841
# Epoch 16/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.0742 - val_accuracy: 0.9836
# Epoch 17/20
# 469/469 [==============================] - 11s 22ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0848 - val_accuracy: 0.9815
# Epoch 18/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0909 - val_accuracy: 0.9817
# Epoch 19/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0744 - val_accuracy: 0.9834
# Epoch 20/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0843 - val_accuracy: 0.9833
